# %% [markdown]
# <a href="https://colab.research.google.com/github/mamoo9811/clinic-app/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list_keys = ['spain','palestine','jordan','serya','iraq']
list_valus = ['madred','jerosalem','amman','dimashq','baghdad']
dic_capitals = dict(zip(list_keys,list_valus))
print(dic_capitals)
# Out:
# {'spain': 'madred', 'palestine': 'jerosalem', 'jordan': 'amman', 'serya': 'dimashq', 'iraq': 'baghdad'}

# %%
a=4
b=9
c=32
max_value = max(a,b,c)
print(max_value)
# Out:
# 32

# %%
massage = 'mahmoud'
cap = massage.upper()
print(massage)
print(cap)
# Out:
# mahmoud
# MAHMOUD

# %%
regular_price  = 300
sale = .2
sale_price = (1-sale)*regular_price
statement= f'the orgnal cost was ${regular_price}, put I purchased it on sale for ${sale_price}.'
print(statement)
# Out:
# the orgnal cost was $300, put I purchased it on sale for $240.0.

# %%
txt = 'hello mahmoud are you homless?'
txt.replace('h','j')
# Out:
# 'jello majmoud are you jomless?'

# %%
first_name = 'mahmoud'
last_name = 'saleh'
address = 'derballot'
specialization = 'cs'
main_reason_for_joining_the_bootcamp = 'To develop myself'
print(f"my name is {first_name} {last_name}, from {address}, i learned{specialization}, and the main reason for joining the bootcamp {main_reason_for_joining_the_bootcamp}")
# Out:
# my name is mahmoud saleh, from derballot, i learnedcs, and the main reason for joining the bootcamp To develop myself

# %%
word_list = ['this', 'is' , 'a' , 'list','of' , 'strings']
random_list = [12, 'frog',['this', 'is' , 'a' , 'list','in','a', 'list'], True, 3.14]
print(word_list)
print(random_list)
# Out:
# ['this', 'is', 'a', 'list', 'of', 'strings']
# [12, 'frog', ['this', 'is', 'a', 'list', 'in', 'a', 'list'], True, 3.14]

# %%
word_list.remove('is')

# %%
word_list.append('new')
print(word_list)
print(random_list[2][3])
# Out:
# ['this', 'of', 'strings', 'new', 'new', 'new']
# list

# %%
word_list + random_list
# Out:
# ['this',
#  'of',
#  'strings',
#  'new',
#  'new',
#  'new',
#  12,
#  'frog',
#  ['this', 'is', 'a', 'list', 'in', 'a', 'list'],
#  True,
#  3.14]

# %%
integer_tuple = (1,2,3,4,5)
random_tuple = (1,'hours', integer_tuple , word_list, False)
print(integer_tuple)
print(random_tuple)
print(random_tuple[0:3])
print(random_list[0:4])
# Out:
# (1, 2, 3, 4, 5)
# (1, 'hours', (1, 2, 3, 4, 5), ['this', 'of', 'strings', 'new', 'new', 'new'], False)
# (1, 'hours', (1, 2, 3, 4, 5))
# [12, 'frog', ['this', 'is', 'a', 'list', 'in', 'a', 'list'], True]

# %%
class Node:
    def _init(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def _init(self):
        self.head = None

    def add(self, data):
        new_node = Node(data)
        if self.head is None:
            self.head = new_node
            return
        current = self.head
        while current.next:
            current = current.next
        current.next = new_node


    def insert_at(self, index, data):
        new_node = Node(data)


        if index == 0:
            new_node.next = self.head
            self.head = new_node
            return True

        current = self.head
        prev = None
        count = 0


        while current and count < index:
            prev = current
            current = current.next
            count += 1


        if count < index:
            print("the psition not found")
            return False


        prev.next = new_node
        new_node.next = current
        return True

    def delete(self, data):
        current = self.head
        prev = None
        while current:
            if current.data == data:
                if prev is None:
                    self.head = current.next
                else:
                    prev.next = current.next
                return True
            prev = current
            current = current.next
        return False

    def update(self, old_data, new_data):
        current = self.head
        while current:
            if current.data == old_data:
                current.data = new_data
                return True
            current = current.next
        return False

    def display(self):
        current = self.head
        result = []
        while current:
            result.append(str(current.data))
            current = current.next
        print(" -> ".join(result))

# %%
ll = LinkedList()
ll.add(10)
ll.add(20)
ll.add(30)
ll.display()

ll.insert_at(1, 15)
ll.display()

ll.insert_at(0, 5)
ll.display()
# Out:
# 10 -> 20 -> 30
# 10 -> 15 -> 20 -> 30
# 5 -> 10 -> 15 -> 20 -> 30

# %%
pip install llist
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.0/43.0 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for llist: filename=llist-0.7.1-cp313-cp313-linux_x86_64.whl size=76660 sha256=3b14ce1356f4809d5da155e5cf97b2e92af19b15ab616b1bfcb30484fd9d0097
#   Stored in directory: /root/.cache/pip/wheels/96/8c/c6/0e548791c3e279d820e2efe612d6070c4bb6ab90bfe3d3f97a
# Successfully built llist
# ...

# %%
import llist
dllist = llist.dllist
dl = dllist([10, 20, 30, 40])
print(dl)
dl.append(50)
print(dl)
dl.appendleft(5)
print(dl)
target_node = dl.nodeat(2)
dl.insert(15, target_node)
print(dl)
dl.popright()
print(dl)
dl.popleft()
print(dl)
node_to_remove = dl.nodeat(1)
dl.remove(node_to_remove)
print(dl)
# Out:
# dllist([10, 20, 30, 40])
# dllist([10, 20, 30, 40, 50])
# dllist([5, 10, 20, 30, 40, 50])
# dllist([5, 10, 15, 20, 30, 40, 50])
# dllist([5, 10, 15, 20, 30, 40])
# dllist([10, 15, 20, 30, 40])
# dllist([10, 20, 30, 40])

# %%
def password_(password):
  if len(password) < 6:
    return False
  elif len(password) > 16:
    return False

  upper_c = False
  lower_c = False
  digit_ = False
  _chars = "$#@"
  chars_ = False

  for char in password:
    if char.isupper():
      upper_c = True
    elif char.islower():
      lower_c = True
    elif char.isdigit():
      digit_ = True
    elif char in _chars:
            chars_ = True

  if lower_c and upper_c and digit_ and chars_:
        return True
  else:
        return False

# %%
print(password_("Mahmo9811#"))
print(password_("Mahmoud"))
print(password_("Mahmo9811"))
# Out:
# True
# False
# False
